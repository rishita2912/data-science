# %%
import pandas as pd

# %%
Data = '{"employee_name": "Rishita", "email": "rishi@gmail.com", "job_profile": [{"title1":"Team Leader","title2":"Sr. Developer"}]}'
pd.read_json(Data)
# Out:
#   employee_name            email  \
# 0       Rishita  rishi@gmail.com
#
#                                          job_profile
# 0  {'title1': 'Team Leader', 'title2': 'Sr. Devel...

# %%
#MatplotLib Tutorial(It is a plotting library and the numeriacal extension of NumPy)
#Provides object oriented API for embedding plots into applications using GUI toolikits like Tkinter.

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
## Simple Examples

x=np.arange(0,10)
y=np.arange(11,21)

# %%
a=np.arange(40,50)
b=np.arange(50,60)

# %%
##plotting using matplotlib

##plt scatter

plt.scatter(x,y,c='r')

# %%
y=x*x

# %%
x = np.arange(1,11)
y= 3*x+5
plt.title("Matplotlib demo")
plt.xlabel("x axis caption")
plt.ylabel("y axis caption")
plt.plot(x,y)
plt.show()

# %%
np.pi
# Out:
# 3.141592653589793

# %%
# Compute the x and y coordinates for points on a sine curve
x = np.arange(0,4 *np.pi,0.1)
y = np.sin(x)
plt.title("Sine wave form")

#Plot the points using matplotlib
plt.plot(x,y)
plt.show()

# %%
## Bar Plot

x = [2,8,10]
y = [11,16,19]

x2 = [3,9,11]
y2 = [6,15,7]
plt.bar(x,y,align = 'center')
plt.bar(x2,y2,color = 'g')
plt.title('Bar graph')
plt.ylabel('Y axis')
plt.xlabel('X axis')

plt.show()

# %%
a = np.array([22,87,5,43,56,73,5,54,11,20,51,5,79,31,27])
plt.hist(a)
plt.title("histogram")
plt.show()

# %%
# Box Plot using Matplotlib

data = [np.random.normal(0, std,100) for std in range(1,4)]

plt.boxplot(data,vert= False, patch_artist= True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2efc9a31790>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2efc9a31d30>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x2efc9a313d0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2efc9a41310>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2efc9a415e0>,
# ...
#  'means': []}

# %%
##Circles are the outliers

data
# Out:
# [array([-1.66350148, -0.69597669, -0.92176583, -0.45743228, -0.36860251,
#         -1.55281225,  0.30359294,  0.95316257, -0.18818764,  1.14785838,
#         -0.85195609,  0.20863782,  0.2896959 ,  0.46427383, -0.09242085,
#          1.65927353, -0.24058385,  1.16379776,  0.51173006,  0.3400718 ,
#          0.18178711,  0.09300072,  1.38079173, -0.34324551,  2.11629325,
#         -1.25100988, -0.70151941, -0.76238267, -0.28678209, -0.66504725,
#         -0.93133522, -0.87651882, -0.6758604 , -0.01101012,  0.92235477,
#         -0.54267668, -0.97856633, -1.20928816,  0.30914882,  1.71945673,
#         -0.74692557, -2.26933501,  0.33823732, -1.30109944,  0.05173232,
#         -0.39439146, -1.57162871,  1.43467476, -0.16687332, -0.96550458,
#         -1.9358862 ,  0.6685246 , -0.19095501,  1.97619842, -0.91498663,
#          1.85693442, -0.94587021, -0.62420525,  0.7373833 ,  0.03263929,
#          0.54262497,  0.53963182, -2.06107664, -0.02675783,  0.17394234,
# ...

# %%
# Data to plot
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [215,130,245,210]
colors = ['gold','yellowgreen','lightcoral','lightskyblue']
explode = (0.1,0,0,0) #explode 1st slice

#Plot
plt.pie(sizes,explode=explode, labels=labels, colors=colors,
       autopct='%1.1%%', shadow=True)

plt.axis('equal')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_47628\2624207308.py in <module>
#       6
#       7 #Plot
# ----> 8 plt.pie(sizes,explode=explode, labels=labels, colors=colors,
#       9        autopct='%1.1%%', shadow=True)
#      10
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2754         textprops=None, center=(0, 0), frame=False,
#    2755         rotatelabels=False, *, normalize=True, data=None):
# -> 2756     return gca().pie(
#    2757         x, explode=explode, labels=labels, colors=colors,
#    2758         autopct=autopct, pctdistance=pctdistance, shadow=shadow,
#
# ...
